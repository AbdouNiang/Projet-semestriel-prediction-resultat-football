# %%
import requests
import json

# %%
url = "https://football-prediction-api.p.rapidapi.com/api/v2/predictions"
headers = {
    "x-rapidapi-host": "football-prediction-api.p.rapidapi.com",
    "x-rapidapi-key": "687d82fb61msh782f8c461f79957p11dda7jsn01d9b4b7c04c"
}
response = requests.get(url, headers=headers)

# %%
data = json.loads(response.text)

# %%
data
# Out:
# {'data': [{'home_team': 'Falkenbergs',
#    'away_team': 'Tvaakers IF',
#    'id': 251115,
#    'market': 'classic',
#    'competition_name': 'Division 1',
#    'prediction': '1',
#    'competition_cluster': 'Sweden',
#    'status': 'pending',
#    'federation': 'UEFA',
#    'is_expired': False,
#    'season': '2023',
#    'result': '',
#    'start_date': '2023-05-17T18:00:00',
#    'last_update_at': '2023-05-17T07:07:56.181027',
#    'odds': {'1': 1.317,
#     'X': 4.775,
#     '2': 7.575,
#     '1X': 1.067,
#     'X2': 3.088,
#     '12': 1.14}},
#   {'home_team': 'Deportivo Pasto',
#    'away_team': 'Envigado FC',
#    'id': 251137,
#    'market': 'classic',
#    'competition_name': 'Categoria Primera A',
#    'prediction': '1',
#    'competition_cluster': 'Colombia',
#    'status': 'pending',
#    'federation': 'CONMEBOL',
#    'is_expired': False,
#    'season': '2023 - Apertura',
#    'result': '',
#    'start_date': '2023-05-18T01:00:00',
#    'last_update_at': '2023-05-17T13:08:52.463205',
#    'odds': {'1': 1.358,
#     'X': 4.334,
#     '2': 9.17,
#     '1X': 1.06,
#     'X2': 3.022,
#     '12': 1.198}},
#   {'home_team': 'Ljungskile',
#    'away_team': 'Vanersborgs IF',
#    'id': 251116,
#    'market': 'classic',
#    'competition_name': 'Division 1',
#    'prediction': '12',
#    'competition_cluster': 'Sweden',
#    'status': 'pending',
#    'federation': 'UEFA',
#    'is_expired': False,
#    'season': '2023',
#    'result': '',
#    'start_date': '2023-05-17T18:00:00',
#    'last_update_at': '2023-05-17T13:08:52.463205',
#    'odds': {'1': 1.908,
#     'X': 3.46,
#     '2': 3.425,
#     '1X': 1.26,
#     'X2': 1.788,
#     '12': 1.255}},
#   {'home_team': 'IF Sylvia',
#    'away_team': 'Orebro Syrianska IF',
#    'id': 251110,
#    'market': 'classic',
#    'competition_name': 'Division 1',
#    'prediction': '12',
#    'competition_cluster': 'Sweden',
#    'status': 'pending',
#    'federation': 'UEFA',
#    'is_expired': False,
#    'season': '2023',
#    'result': '',
#    'start_date': '2023-05-17T18:00:00',
#    'last_update_at': '2023-05-17T13:08:52.463205',
#    'odds': {'1': 2.072,
#     'X': 3.535,
#     '2': 2.885,
#     '1X': 1.345,
#     'X2': 1.655,
#     '12': 1.237}},
#   {'home_team': 'Orlando City',
#    'away_team': 'New York City',
#    'id': 251249,
#    'market': 'classic',
#    'competition_name': 'Major League Soccer',
#    'prediction': 'X2',
#    'competition_cluster': 'USA',
#    'status': 'pending',
#    'federation': 'CONCACAF',
#    'is_expired': False,
#    'season': '2023',
#    'result': '',
#    'start_date': '2023-05-18T00:30:00',
#    'last_update_at': '2023-05-17T13:08:52.463205',
#    'odds': {'1': 2.207,
#     'X': 3.277,
#     '2': 3.273,
#     '1X': 1.32,
#     'X2': 1.652,
#     '12': 1.318}},
#   {'home_team': 'Manchester City',
#    'away_team': 'Real Madrid',
#    'id': 251071,
#    'market': 'classic',
#    'competition_name': 'Semi Finals',
#    'prediction': '1',
#    'competition_cluster': 'Champions League',
#    'status': 'pending',
#    'federation': 'UEFA',
#    'is_expired': False,
#    'season': None,
#    'result': '',
#    'start_date': '2023-05-17T20:00:00',
#    'last_update_at': '2023-05-17T13:08:52.463205',
#    'odds': {'1': 1.599,
#     'X': 4.344,
#     '2': 5.307,
#     '1X': 1.155,
#     'X2': 2.34,
#     '12': 1.213}},
#   {'home_team': 'Middlesbrough',
#    'away_team': 'Coventry',
#    'id': 251072,
#    'market': 'classic',
#    'competition_name': 'Championship Playoff',
#    'prediction': '1',
#    'competition_cluster': 'England',
#    'status': 'pending',
#    'federation': 'UEFA',
#    'is_expired': False,
#    'season': '2022 - 2023',
#    'result': '',
#    'start_date': '2023-05-17T20:00:00',
#    'last_update_at': '2023-05-17T13:08:52.463205',
#    'odds': {'1': 1.848,
#     'X': 3.457,
#     '2': 4.412,
#     '1X': 1.198,
#     'X2': 1.932,
#     '12': 1.3}},
#   {'home_team': 'National Bank SC',
#    'away_team': 'Ismaily Ismailiya',
#    'id': 251145,
#    'market': 'classic',
#    'competition_name': 'Premier League',
#    'prediction': '12',
#    'competition_cluster': 'Egypt',
#    'status': 'pending',
#    'federation': 'CAF',
#    'is_expired': False,
#    'season': '2022 - 2023',
#    'result': '',
#    'start_date': '2023-05-17T18:00:00',
#    'last_update_at': '2023-05-17T13:08:52.463205',
#    'odds': {'1': 2.418,
#     'X': 2.925,
#     '2': 2.947,
#     '1X': 1.362,
#     'X2': 1.51,
#     '12': 1.36}},
#   {'home_team': 'Torns IF',
#    'away_team': 'Lunds',
#    'id': 251118,
#    'market': 'classic',
#    'competition_name': 'Division 1',
#    'prediction': '2',
#    'competition_cluster': 'Sweden',
#    'status': 'pending',
#    'federation': 'UEFA',
#    'is_expired': False,
#    'season': '2023',
#    'result': '',
#    'start_date': '2023-05-17T18:00:00',
#    'last_update_at': '2023-05-17T13:08:52.463205',
#    'odds': {'1': 3.42,
#     'X': 3.403,
#     '2': 1.933,
#     '1X': 1.753,
#     'X2': 1.26,
#     '12': 1.267}},
#   {'home_team': 'FK Liepaja',
#    'away_team': 'Rigas Futbola Skola',
#    'id': 251103,
#    'market': 'classic',
#    'competition_name': 'Virsliga',
#    'prediction': '2',
#    'competition_cluster': 'Latvia',
#    'status': 'pending',
#    'federation': 'UEFA',
#    'is_expired': False,
#    'season': '2023',
#    'result': '',
#    'start_date': '2023-05-17T16:00:00',
#    'last_update_at': '2023-05-17T13:08:52.463205',
#    'odds': {'1': 5.75,
#     'X': 3.885,
#     '2': 1.487,
#     '1X': 2.425,
#     'X2': 1.105,
#     '12': 1.207}},
#   {'home_team': 'Sumgayit FC',
#    'away_team': 'Sabah Baku',
#    'id': 251080,
#    'market': 'classic',
#    'competition_name': 'Premier League',
#    'prediction': '2',
#    'competition_cluster': 'Azerbaijan',
#    'status': 'pending',
#    'federation': 'UEFA',
#    'is_expired': False,
#    'season': '2022 - 2023',
#    'result': '',
#    'start_date': '2023-05-17T16:30:00',
#    'last_update_at': '2023-05-17T13:08:52.463205',
#    'odds': {'1': 6.36,
#     'X': 4.394,
#     '2': 1.378,
#     '1X': 2.774,
#     'X2': 1.084,
#     '12': 1.168}},
#   {'home_team': 'Independiente Medellin',
#    'away_team': 'Union Magdalena',
#    'id': 251139,
#    'market': 'classic',
#    'competition_name': 'Categoria Primera A',
#    'prediction': '1',
#    'competition_cluster': 'Colombia',
#    'status': 'pending',
#    'federation': 'CONMEBOL',
#    'is_expired': False,
#    'season': '2023 - Apertura',
#    'result': '',
#    'start_date': '2023-05-18T01:00:00',
#    'last_update_at': '2023-05-17T13:08:52.463205',
#    'odds': {'1': 1.316,
#     'X': 4.85,
#     '2': 9.04,
#     '1X': 1.062,
#     'X2': 3.268,
#     '12': 1.172}},
#   {'home_team': 'Minnesota United',
#    'away_team': 'Houston Dynamo',
#    'id': 251253,
#    'market': 'classic',
#    'competition_name': 'Major League Soccer',
#    'prediction': '1',
#    'competition_cluster': 'USA',
#    'status': 'pending',
#    'federation': 'CONCACAF',
#    'is_expired': False,
#    'season': '2023',
#    'result': '',
#    'start_date': '2023-05-18T01:30:00',
#    'last_update_at': '2023-05-17T13:08:52.463205',
#    'odds': {'1': 1.82,
#     'X': 3.583,
#     '2': 4.33,
#     '1X': 1.208,
#     'X2': 1.933,
#     '12': 1.282}},
#   {'home_team': 'Deportivo Cali',
#    'away_team': 'Boyaca Chico',
#    'id': 251136,
#    'market': 'classic',
#    'competition_name': 'Categoria Primera A',
#    'prediction': '1X',
#    'competition_cluster': 'Colombia',
#    'status': 'pending',
#    'federation': 'CONMEBOL',
#    'is_expired': False,
#    'season': '2023 - Apertura',
#    'result': '',
#    'start_date': '2023-05-18T01:00:00',
#    'last_update_at': '2023-05-17T13:08:52.463205',
#    'odds': {'1': 2.042,
#     'X': 3.228,
#     '2': 3.572,
#     '1X': 1.274,
#     'X2': 1.732,
#     '12': 1.334}},
#   {'home_team': 'Rionegro',
#    'away_team': 'Jaguares de Cordoba',
#    'id': 251142,
#    'market': 'classic',
#    'competition_name': 'Categoria Primera A',
#    'prediction': '1',
#    'competition_cluster': 'Colombia',
#    'status': 'pending',
#    'federation': 'CONMEBOL',
#    'is_expired': False,
#    'season': '2023 - Apertura',
#    'result': '',
#    'start_date': '2023-05-18T01:00:00',
#    'last_update_at': '2023-05-17T13:08:52.463205',
#    'odds': {'1': 1.584,
#     'X': 3.784,
#     '2': 5.53,
#     '1X': 1.136,
#     'X2': 2.316,
#     '12': 1.246}},
#   {'home_team': 'FH Hafnarfjordur',
#    'away_team': 'Njardvik',
#    'id': 251097,
#    'market': 'classic',
#    'competition_name': 'Visa bikarinn',
#    'prediction': '1',
#    'competition_cluster': 'Iceland',
#    'status': 'pending',
#    'federation': 'UEFA',
#    'is_expired': False,
#    'season': '2023',
#    'result': '',
#    'start_date': '2023-05-17T20:15:00',
#    'last_update_at': '2023-05-17T13:08:52.463205',
#    'odds': {'1': 1.337,
#     'X': 5.083,
#     '2': 6.817,
#     '1X': 1.087,
#     'X2': 3.11,
#     '12': 1.143}},
#   {'home_team': 'Tacuary Asuncion',
#    'away_team': 'Guarani Asuncion',
#    'id': 251237,
#    'market': 'classic',
#    'competition_name': 'Primera Division',
#    'prediction': '2',
#    'competition_cluster': 'Paraguay',
#    'status': 'pending',
#    'federation': 'CONMEBOL',
#    'is_expired': False,
#    'season': '2023 - Apertura',
#    'result': '',
#    'start_date': '2023-05-18T01:30:00',
#    'last_update_at': '2023-05-17T13:08:52.463205',
#    'odds': {'1': 3.14,
#     'X': 3.138,
#     '2': 2.152,
#     '1X': 1.632,
#     'X2': 1.312,
#     '12': 1.32}},
#   {'home_team': 'Carlos A. Mannucci',
#    'away_team': 'Universidad de Cajamarca',
#    'id': 251180,
#    'market': 'classic',
#    'competition_name': 'Liga 1',
#    'prediction': '1X',
#    'competition_cluster': 'Peru',
#    'status': 'pending',
#    'federation': 'CONMEBOL',
#    'is_expired': False,
#    'season': '2023 - Apertura',
#    'result': '',
#    'start_date': '2023-05-17T21:00:00',
#    'last_update_at': '2023-05-17T13:08:52.463205',
#    'odds': {'1': 1.933,
#     'X': 3.294,
#     '2': 3.654,
#     '1X': 1.246,
#     'X2': 1.781,
#     '12': 1.296}},
#   {'home_team': 'Columbus Crew',
#    'away_team': 'Los Angeles Galaxy',
#    'id': 251247,
#    'market': 'classic',
#    'competition_name': 'Major League Soccer',
#    'prediction': '1',
#    'competition_cluster': 'USA',
#    'status': 'pending',
#    'federation': 'CONCACAF',
#    'is_expired': False,
#    'season': '2023',
#    'result': '',
#    'start_date': '2023-05-18T00:30:00',
#    'last_update_at': '2023-05-17T13:08:52.463205',
#    'odds': {'1': 1.813,
#     'X': 3.832,
#     '2': 3.983,
#     '1X': 1.23,
#     'X2': 1.957,
#     '12': 1.252}},
#   {'home_team': 'Once Caldas',
#    'away_team': 'Santa Fe Bogota',
#    'id': 251141,
#    'market': 'classic',
#    'competition_name': 'Categoria Primera A',
#    'prediction': '12',
#    'competition_cluster': 'Colombia',
#    'status': 'pending',
#    'federation': 'CONMEBOL',
#    'is_expired': False,
#    'season': '2023 - Apertura',
#    'result': '',
#    'start_date': '2023-05-18T01:00:00',
#    'last_update_at': '2023-05-17T13:08:52.463205',
#    'odds': {'1': 2.87,
#     'X': 3.17,
#     '2': 2.43,
#     '1X': 1.536,
#     'X2': 1.394,
#     '12': 1.34}},
#   {'home_team': 'Millonarios Bogota',
#    'away_team': 'La Equidad Bogota',
#    'id': 251140,
#    'market': 'classic',
#    'competition_name': 'Categoria Primera A',
#    'prediction': '1',
#    'competition_cluster': 'Colombia',
#    'status': 'pending',
#    'federation': 'CONMEBOL',
#    'is_expired': False,
#    'season': '2023 - Apertura',
#    'result': '',
#    'start_date': '2023-05-18T01:00:00',
#    'last_update_at': '2023-05-17T13:08:52.463205',
#    'odds': {'1': 1.62,
#     'X': 3.694,
#     '2': 5.25,
#     '1X': 1.146,
#     'X2': 2.232,
#     '12': 1.258}},
#   {'home_team': 'Atlanta United',
#    'away_team': 'Colorado Rapids',
#    'id': 251245,
#    'market': 'classic',
#    'competition_name': 'Major League Soccer',
#    'prediction': '1',
#    'competition_cluster': 'USA',
#    'status': 'pending',
#    'federation': 'CONCACAF',
#    'is_expired': False,
#    'season': '2023',
#    'result': '',
#    'start_date': '2023-05-18T00:30:00',
#    'last_update_at': '2023-05-17T13:08:52.463205',
#    'odds': {'1': 1.692,
#     'X': 3.973,
#     '2': 4.597,
#     '1X': 1.183,
#     'X2': 2.12,
#     '12': 1.233}},
#   {'home_team': 'FC Cincinnati',
#    'away_team': 'CF Montreal',
#    'id': 251248,
#    'market': 'classic',
#    'competition_name': 'Major League Soccer',
#    'prediction': '1',
#    'competition_cluster': 'USA',
#    'status': 'pending',
#    'federation': 'CONCACAF',
#    'is_expired': False,
#    'season': '2023',
#    'result': '',
#    'start_date': '2023-05-18T00:30:00',
#    'last_update_at': '2023-05-17T13:08:52.463205',
#    'odds': {'1': 1.608,
#     'X': 4.0,
#     '2': 5.258,
#     '1X': 1.148,
#     'X2': 2.288,
#     '12': 1.225}},
#   {'home_team': 'Sandvikens IF',
#    'away_team': 'Taby FK',
#    'id': 251111,
#    'market': 'classic',
#    'competition_name': 'Division 1',
#    'prediction': '1',
#    'competition_cluster': 'Sweden',
#    'status': 'pending',
#    'federation': 'UEFA',
#    'is_expired': False,
#    'season': '2023',
#    'result': '',
#    'start_date': '2023-05-17T18:00:00',
#    'last_update_at': '2023-05-17T13:08:52.463205',
#    'odds': {'1': 1.467,
#     'X': 4.318,
#     '2': 5.312,
#     '1X': 1.122,
#     'X2': 2.493,
#     '12': 1.17}},
#   {'home_team': 'CR Belouizdad',
#    'away_team': 'RC Arbaa',
#    'id': 251124,
#    'market': 'classic',
#    'competition_name': 'Championnat National',
#    'prediction': '1',
#    'competition_cluster': 'Algeria',
#    'status': 'pending',
#    'federation': 'CAF',
#    'is_expired': False,
#    'season': '2022 - 2023',
#    'result': '',
#    'start_date': '2023-05-17T16:00:00',
#    'last_update_at': '2023-05-17T13:08:52.463205',
#    'odds': {'1': 1.283,
#     'X': 4.733,
#     '2': 9.767,
#     '1X': 1.03,
#     'X2': 3.31,
#     '12': 1.15}},
#   {'home_team': 'Real Salt Lake',
#    'away_team': 'Portland Timbers',
#    'id': 251255,
#    'market': 'classic',
#    'competition_name': 'Major League Soccer',
#    'prediction': 'X2',
#    'competition_cluster': 'USA',
#    'status': 'pending',
#    'federation': 'CONCACAF',
#    'is_expired': False,
#    'season': '2023',
#    'result': '',
#    'start_date': '2023-05-18T02:30:00',
#    'last_update_at': '2023-05-17T13:08:52.463205',
#    'odds': {'1': 1.863,
#     'X': 3.682,
#     '2': 3.877,
#     '1X': 1.243,
#     'X2': 1.892,
#     '12': 1.262}},
#   {'home_team': 'Karlstad Fotboll',
#    'away_team': 'Hammarby Talang FF',
#    'id': 251108,
#    'market': 'classic',
#    'competition_name': 'Division 1',
#    'prediction': '1X',
#    'competition_cluster': 'Sweden',
#    'status': 'pending',
#    'federation': 'UEFA',
#    'is_expired': False,
#    'season': '2023',
#    'result': '',
#    'start_date': '2023-05-17T17:30:00',
#    'last_update_at': '2023-05-17T13:08:52.463205',
#    'odds': {'1': 2.085,
#     'X': 3.483,
#     '2': 2.888,
#     '1X': 1.332,
#     'X2': 1.64,
#     '12': 1.24}},
#   {'home_team': 'Binacional',
#    'away_team': 'Sporting Cristal',
#    'id': 251239,
#    'market': 'classic',
#    'competition_name': 'Liga 1',
#    'prediction': '1X',
#    'competition_cluster': 'Peru',
#    'status': 'pending',
#    'federation': 'CONMEBOL',
#    'is_expired': False,
#    'season': '2023 - Apertura',
#    'result': '',
#    'start_date': '2023-05-18T01:00:00',
#    'last_update_at': '2023-05-17T13:08:52.463205',
#    'odds': {'1': 2.215,
#     'X': 3.317,
#     '2': 2.947,
#     '1X': 1.365,
#     'X2': 1.598,
#     '12': 1.29}},
#   {'home_team': 'CS Constantine',
#    'away_team': 'JS Saoura',
#    'id': 251125,
#    'market': 'classic',
#    'competition_name': 'Championnat National',
#    'prediction': '1',
#    'competition_cluster': 'Algeria',
#    'status': 'pending',
#    'federation': 'CAF',
#    'is_expired': False,
#    'season': '2022 - 2023',
#    'result': '',
#    'start_date': '2023-05-17T16:00:00',
#    'last_update_at': '2023-05-17T13:08:52.463205',
#    'odds': {'1': 1.624,
#     'X': 3.34,
#     '2': 5.56,
#     '1X': 1.117,
#     'X2': 2.158,
#     '12': 1.278}},
#   {'home_team': 'Philadelphia Union',
#    'away_team': 'D.C. United',
#    'id': 251250,
#    'market': 'classic',
#    'competition_name': 'Major League Soccer',
#    'prediction': '1',
#    'competition_cluster': 'USA',
#    'status': 'pending',
#    'federation': 'CONCACAF',
#    'is_expired': False,
#    'season': '2023',
#    'result': '',
#    'start_date': '2023-05-18T00:30:00',
#    'last_update_at': '2023-05-17T13:08:52.463205',
#    'odds': {'1': 1.622,
#     'X': 3.873,
#     '2': 5.283,
#     '1X': 1.147,
#     'X2': 2.262,
#     '12': 1.242}},
#   {'home_team': 'Nashville SC',
#    'away_team': 'Inter Miami',
#    'id': 251254,
#    'market': 'classic',
#    'competition_name': 'Major League Soccer',
#    'prediction': '1',
#    'competition_cluster': 'USA',
#    'status': 'pending',
#    'federation': 'CONCACAF',
#    'is_expired': False,
#    'season': '2023',
#    'result': '',
#    'start_date': '2023-05-18T01:30:00',
#    'last_update_at': '2023-05-17T13:08:52.463205',
#    'odds': {'1': 1.63,
#     'X': 3.85,
#     '2': 5.317,
#     '1X': 1.148,
#     'X2': 2.245,
#     '12': 1.243}},
#   {'home_team': 'Deportes Tolima',
#    'away_team': 'Atletico Nacional',
#    'id': 251135,
#    'market': 'classic',
#    'competition_name': 'Categoria Primera A',
#    'prediction': '1X',
#    'competition_cluster': 'Colombia',
#    'status': 'pending',
#    'federation': 'CONMEBOL',
#    'is_expired': False,
#    'season': '2023 - Apertura',
#    'result': '',
#    'start_date': '2023-05-18T01:00:00',
#    'last_update_at': '2023-05-17T13:08:52.463205',
#    'odds': {'1': 2.206,
#     'X': 3.17,
#     '2': 3.216,
#     '1X': 1.326,
#     'X2': 1.634,
#     '12': 1.336}},
#   {'home_team': 'KF Tirana',
#    'away_team': 'Partizani Tirana',
#    'id': 251077,
#    'market': 'classic',
#    'competition_name': 'Superliga',
#    'prediction': '12',
#    'competition_cluster': 'Albania',
#    'status': 'pending',
#    'federation': 'UEFA',
#    'is_expired': False,
#    'season': '2022 - 2023',
#    'result': '',
#    'start_date': '2023-05-17T17:30:00',
#    'last_update_at': '2023-05-17T13:08:52.463205',
#    'odds': {'1': 2.06,
#     'X': 3.265,
#     '2': 3.35,
#     '1X': 1.29,
#     'X2': 1.65,
#     '12': 1.29}},
#   {'home_team': 'Atletico Bucaramanga',
#    'away_team': 'America de Cali',
#    'id': 251133,
#    'market': 'classic',
#    'competition_name': 'Categoria Primera A',
#    'prediction': '12',
#    'competition_cluster': 'Colombia',
#    'status': 'pending',
#    'federation': 'CONMEBOL',
#    'is_expired': False,
#    'season': '2023 - Apertura',
#    'result': '',
#    'start_date': '2023-05-18T01:00:00',
#    'last_update_at': '2023-05-17T13:08:52.463205',
#    'odds': {'1': 2.406,
#     'X': 3.248,
#     '2': 2.802,
#     '1X': 1.416,
#     'X2': 1.534,
#     '12': 1.328}},
#   {'home_team': 'Shirak',
#    'away_team': 'Ararat-Armenia',
#    'id': 251079,
#    'market': 'classic',
#    'competition_name': 'Premier League',
#    'prediction': '2',
#    'competition_cluster': 'Armenia',
#    'status': 'pending',
#    'federation': 'UEFA',
#    'is_expired': False,
#    'season': '2022 - 2023',
#    'result': '',
#    'start_date': '2023-05-17T17:00:00',
#    'last_update_at': '2023-05-17T13:08:52.463205',
#    'odds': {'1': 7.537,
#     'X': 4.26,
#     '2': 1.347,
#     '1X': 2.898,
#     'X2': 1.058,
#     '12': 1.178}},
#   {'home_team': 'Sportivo Luqueno',
#    'away_team': 'Cerro Porteno',
#    'id': 251158,
#    'market': 'classic',
#    'competition_name': 'Primera Division',
#    'prediction': '2',
#    'competition_cluster': 'Paraguay',
#    'status': 'pending',
#    'federation': 'CONMEBOL',
#    'is_expired': False,
#    'season': '2023 - Apertura',
#    'result': '',
#    'start_date': '2023-05-17T23:00:00',
#    'last_update_at': '2023-05-17T13:08:52.463205',
#    'odds': {'1': 4.195,
#     'X': 3.462,
#     '2': 1.757,
#     '1X': 1.965,
#     'X2': 1.19,
#     '12': 1.268}},
#   {'home_team': 'FC Dallas',
#    'away_team': 'Vancouver Whitecaps',
#    'id': 251252,
#    'market': 'classic',
#    'competition_name': 'Major League Soccer',
#    'prediction': '1',
#    'competition_cluster': 'USA',
#    'status': 'pending',
#    'federation': 'CONCACAF',
#    'is_expired': False,
#    'season': '2023',
#    'result': '',
#    'start_date': '2023-05-18T01:30:00',
#    'last_update_at': '2023-05-17T13:08:52.463205',
#    'odds': {'1': 1.983,
#     'X': 3.477,
#     '2': 3.727,
#     '1X': 1.263,
#     'X2': 1.787,
#     '12': 1.285}},
#   {'home_team': 'Toronto FC',
#    'away_team': 'New York Red Bulls',
#    'id': 251251,
#    'market': 'classic',
#    'competition_name': 'Major League Soccer',
#    'prediction': 'X2',
#    'competition_cluster': 'USA',
#    'status': 'pending',
#    'federation': 'CONCACAF',
#    'is_expired': False,
#    'season': '2023',
#    'result': '',
#    'start_date': '2023-05-18T00:30:00',
#    'last_update_at': '2023-05-17T13:08:52.463205',
#    'odds': {'1': 2.545,
#     'X': 3.088,
#     '2': 2.895,
#     '1X': 1.398,
#     'X2': 1.487,
#     '12': 1.352}},
#   {'home_team': 'Atletico Huila',
#    'away_team': 'Junior Barranquilla',
#    'id': 251134,
#    'market': 'classic',
#    'competition_name': 'Categoria Primera A',
#    'prediction': '2',
#    'competition_cluster': 'Colombia',
#    'status': 'pending',
#    'federation': 'CONMEBOL',
#    'is_expired': False,
#    'season': '2023 - Apertura',
#    'result': '',
#    'start_date': '2023-05-18T01:00:00',
#    'last_update_at': '2023-05-17T13:08:52.463205',
#    'odds': {'1': 4.476,
#     'X': 3.588,
#     '2': 1.732,
#     '1X': 2.048,
#     'X2': 1.192,
#     '12': 1.276}},
#   {'home_team': 'Charlotte FC',
#    'away_team': 'Chicago Fire',
#    'id': 251246,
#    'market': 'classic',
#    'competition_name': 'Major League Soccer',
#    'prediction': '1',
#    'competition_cluster': 'USA',
#    'status': 'pending',
#    'federation': 'CONCACAF',
#    'is_expired': False,
#    'season': '2023',
#    'result': '',
#    'start_date': '2023-05-18T00:30:00',
#    'last_update_at': '2023-05-17T14:07:28.750493',
#    'odds': {'1': 1.993,
#     'X': 3.607,
#     '2': 3.5,
#     '1X': 1.287,
#     'X2': 1.785,
#     '12': 1.273}}]}
